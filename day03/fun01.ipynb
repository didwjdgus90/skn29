# %% [markdown]
# # 순환문과 함수
# - 매개변수 : 기본이 positional 즉 순서가 중요
# - 사용자가 순서를 원하는대로 입력하려면... 반드시 key:value 형태로
#
# - 사용자가 값을 주지않으면 기본값으로 대처하는 기본 매개변수
#
# - 사용자가 몇개의 값을 줄지 모르는 상황이면 하나의 변수로 다 받아들이는 가변매개변수 *번수명

# %%
# 자동차 조집
def make_car(body_type, wheel_count): # SUV, 세단 . 타이어 몇개
    return f'완성! 차체 : {body_type} 바퀴: {wheel_count}'

# %%
print(make_car( 4,'SUV')) # 호출순서가 비정상
print(make_car('SUv', 4)) # 호출순서가 정상

print(make_car( wheel_count=4,body_type='SUV')) # 키워드 매핑
# Out:
# 완성! 차체 : 4 바퀴: SUV
# 완성! 차체 : SUv 바퀴: 4
# 완성! 차체 : SUV 바퀴: 4
