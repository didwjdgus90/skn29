# %%
# %conda install mysql-connector-python
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\Playdata\miniconda3\envs\test_env
#
#   added / updated specs:
#     - mysql-connector-python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mysql-common-9.3.0         |       h0b12ad4_5         619 KB
#     mysql-connector-python-9.3.0|  py310h5da7b33_0         770 KB
#     mysql-libs-9.3.0           |       hcb0c519_5         1.2 MB
#     ------------------------------------------------------------
#                                            Total:         2.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   mysql-common       pkgs/main/win-64::mysql-common-9.3.0-h0b12ad4_5
#   mysql-connector-p~ pkgs/main/win-64::mysql-connector-python-9.3.0-py310h5da7b33_0
# ...

# %%
import mysql.connector as mc
from mysql.connector import Error

# %%
def insert_data(conn):
    # 데이터 삽입
    sql = 'INSERT INTO customers' \
    '(name, email, phone, point, grade, join_date, last_purchase_date)' \
    ' VALUES(%s,%s,%s,%s,%s,%s,%s)'

    values = ('홍길동2', 'hong2.cs@email.com', '010-1111-0001', 5000, 'Gold', '2023-01-15', '2024-02-20')

    cursor = conn.cursor()
    cursor.execute(sql, values)
    conn.commit()

# %%
try :  # 데이터베이스 연결중 오류 나면
    conn = mc.connect( # DB 연결 
        host = 'localhost', # DB 주소(127.0.0.1)
        user = 'root', #DB 사용자 이름
        password = '!didwjdgus16', # DB 비밀번호
        database = 'shop_db' #사용할 DB
    )
    if conn.is_connected: 
            print('접속성공')
    insert_data(conn)   
except Error as e:
    print(f'데이터베이스 오류 : {e}')
finally:
    if conn:
        conn.close()
        print('연결 해제')
# Out:
# 접속성공
# 데이터베이스 오류 : 1062 (23000): Duplicate entry 'hong2.cs@email.com' for key 'customers.email'
# 연결 해제
