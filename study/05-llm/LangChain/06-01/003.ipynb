# %%
##########################################################################################
# SuperVisor 패턴 : 하나의 상위노드가 여러 작업자를 배치해서 각 작업의 결과를 모아서 최종 답변
##########################################################################################
# 초안
# 비평
# 품질 점수
# 80점 미만
# 재작성

#       Supervisor
#       Reasearcher
#       Writer
#       Critic
# faile         pass
# Writer        Finalizer

# %%
# 슈퍼바이저를 한단계 더 발전시켜서 에이전트 개념확장
#                     Supervisor
#                          │
#         ┌────────────────┼────────────────┐
#         │                │                │
#         ▼                ▼                ▼
#    ResearchAgent    WriterAgent    CriticAgent
#         │                │                │
#         └────────────────┼────────────────┘
#                          ▼
#                     Finalizer

#  Supervisor--> 오케스트레이터

# %%
import os
import re
from pathlib import Path
import chromadb
from chromadb.utils import embedding_functions
from typing_extensions import TypedDict
from langgraph.graph import StateGraph,START,END
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

# openai client
client = OpenAI()
# 임베딩 함수  허깅페이스 :This is a sentence-transformers model 찾아라.
st_ef =  embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name='jhgan/ko-sroberta-multitask'
)
chroma_client = chromadb.PersistentClient()  #DB
collection = chroma_client.get_or_create_collection(   # table
    name = 'Supervisor_MultiAgent',
    embedding_function=st_ef
)

if collection.count() == 0:
    collection.add(
        ids=[
            "doc_langgraph",
            "doc_react",
            "doc_rag",
            "doc_supervisor",
        ],
        documents=[
            "LangGraph는 상태 기반 그래프로 역할별 노드를 연결한다.",
            "ReAct는 생각과 행동을 번갈아 수행하며 중간 도구를 사용할 수 있다.",
            "RAG는 벡터DB에서 찾은 근거를 답변 생성에 사용한다.",
            "Supervisor는 여러 에이전트의 순서와 책임을 조율한다.",
        ],
    )

# --------------------------------------------------
# State
# --------------------------------------------------

class SupervisorState(TypedDict):
    task: str
    research_notes: str
    draft: str
    critique: str
    score: int
    revision_count: int
    final_answer: str

# --------------------------------------------------
# Research Agent
# --------------------------------------------------

def researcher(state: SupervisorState):

    result = collection.query(
        query_texts=[state["task"]],
        n_results=3,
    )

    context = "\n".join(
        result["documents"][0]
    )

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=[
            {
                "role": "system",
                "content":
                "당신은 Research Agent이다. "
                "근거를 간결하게 정리하라."
            },
            {
                "role": "user",
                "content":
                f"""
작업:
{state['task']}

근거:
{context}
"""
            }
        ]
    )

    return {
        "research_notes":
        response.choices[0].message.content.strip()
    }


# --------------------------------------------------
# Writer Agent
# --------------------------------------------------

def writer(state: SupervisorState):

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=[
            {
                "role": "system",
                "content":
                "당신은 Writer Agent이다."
            },
            {
                "role": "user",
                "content":
                f"""
작업:
{state['task']}

조사내용:
{state['research_notes']}

이전 비평:
{state['critique']}

비평을 반영하여 설명문을 작성하라.
"""
            }
        ]
    )

    return {
        "draft":
        response.choices[0].message.content.strip()
    }


# --------------------------------------------------
# Critic Agent
# --------------------------------------------------

def critic(state: SupervisorState):
    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=[
            {
                "role": "system",
                "content":
                """
당신은 Critic Agent이다.

반드시 아래 형식으로 답한다.

SCORE: 숫자

CRITIQUE:
비평 내용
"""
            },
            {
                "role": "user",
                "content":
                f"""
작업:
{state['task']}

초안:
{state['draft']}
"""
            }
        ]
    )

    text = response.choices[0].message.content.strip()

    score = 50

    try:
        import re

        match = re.search(
            r"SCORE:\s*(\d+)",
            text
        )

        if match:
            score = int(match.group(1))

    except Exception:
        pass

    return {
        "critique": text,
        "score": score,
    }


# --------------------------------------------------
# Supervisor
# --------------------------------------------------

def supervisor(state: SupervisorState):
    score = state["score"]
    revision_count = state["revision_count"]
    if score >= 80:
        return {}

    return {
        "revision_count":
        revision_count + 1
    }

# --------------------------------------------------
# Routing
# --------------------------------------------------

def route_after_critic(
    state: SupervisorState
):
    if state["score"] >= 80:
        return "finalizer"
    
    if state["revision_count"] >= 2:
        return "finalizer"

    return "writer"


# --------------------------------------------------
# Finalizer
# --------------------------------------------------

def finalizer(state: SupervisorState):

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=[
            {
                "role": "system",
                "content":
                "최종 답변 작성 Agent"
            },
            {
                "role": "user",
                "content":
                f"""
작업:
{state['task']}

조사:
{state['research_notes']}

최종 초안:
{state['draft']}

비평:
{state['critique']}

최종 답변 작성
"""
            }
        ]
    )

    return {
        "final_answer":
        response.choices[0].message.content.strip()
    }


# --------------------------------------------------
# Graph
# --------------------------------------------------

workflow = StateGraph(
    SupervisorState
)

workflow.add_node(    "researcher",    researcher)
workflow.add_node(    "writer",    writer)
workflow.add_node(    "critic",    critic)
workflow.add_node(    "supervisor",    supervisor)
workflow.add_node(    "finalizer",    finalizer)
workflow.add_edge(    START,    "researcher")
workflow.add_edge(    "researcher",    "writer")
workflow.add_edge(    "writer",    "critic")
workflow.add_edge(    "critic",    "supervisor")
workflow.add_conditional_edges(
    "supervisor",
    route_after_critic,
    {
        "writer": "writer",
        "finalizer": "finalizer",
    }
)
workflow.add_edge(    "finalizer",    END)
app = workflow.compile()

# --------------------------------------------------
# Run
# --------------------------------------------------

result = app.invoke(
    {
        "task":"LangGraph Supervisor 기반 멀티 에이전트 패턴 설명",
        "research_notes": "",
        "draft": "",
        "critique": "",
        "score": 0,
        "revision_count": 0,
        "final_answer": "",
    }
)

print("\n=== FINAL ===")
print(result["final_answer"])

print("\n=== SCORE ===")
print(result["score"])

print("\n=== REVISION ===")
print(result["revision_count"])

print("\n=== CRITIQUE ===")
print(result["critique"])
# Out:
# === FINAL ===
# 아래는 **LangGraph Supervisor 기반 멀티 에이전트 패턴**을, 비평에서 요구한 대로 **“state가 그래프 요소(라우팅/전이/종료)와 어떻게 연결되는지”** 관점에 맞춰 **역할 경계(누가 상태를 갱신하고, 누가 라우팅/종료를 결정하는지)**까지 정리한 최종 설명입니다.
#
# ---
#
# ## 1) 전체 구조(역할을 고정: 상태 갱신 주체 vs 라우팅 결정 주체)
#
# 이 패턴의 핵심은 역할을 분리해 **불일치 없이** 고정하는 것입니다.
#
# - **하위 에이전트(Worker 노드)**: 작업 수행 후 결과를 **state에 기록**(상태 갱신 주체)
# - **Supervisor 노드**: 현재 state를 **읽고**, 다음에 어떤 노드로 보낼지/언제 끝낼지 **결정**(라우팅·종료 결정 주체)
#
# > 즉, “state를 업데이트하는 사람”과 “state를 보고 다음 전이를 고르는 사람”을 문장에서도 일관되게 고정합니다.
#
# ---
#
# ## 2) “상태(state) 기반 그래프”가 의미하는 것(라우팅/전이/조건의 연결고리)
#
# LangGraph의 그래프 전이는 보통 다음 3요소가 함께 맞물립니다.
#
# 1. **state 스키마**: 그래프가 공유하는 데이터(예: `messages`, `next_worker`, `task_status`, `confidence` 등)
# 2. **조건부 엣지(conditional routing)**: 어떤 함수를 통해 “다음 노드”를 고름
# 3. **END(종료)**: 종료 조건이 만족되면 END로 전이
#
# 이때 “상태 기반”은 곧 이런 의미입니다.
#
# - **라우팅 조건이 state 필드 값에 의해 결정**된다.
# - 따라서 “다음 노드로 이동” 및 “종료 여부”가 모두 **state 값 변화의 결과**로 나타난다.
#
# ---
#
# ## 3) state 필드(예시) — 라우팅 키 + 종료 키를 명확히 두기
#
# 예를 들어 아래처럼 state를 설계하면 구현이 거의 그대로 이어집니다.
#
# ```text
# State {
#   messages: [...],            // 대화/작업 기록
#   next_worker: "planner" | "researcher" | "writer" | "verifier" | null,
#   task_status: "running" | "done" | "failed",
#   iteration_count: int,
#   confidence: float,         // 품질/확신 점수(선택)
#   artifacts: {...}          // 중간 산출물(선택)
# }
# ```
#
# 여기서 중요한 포인트는:
# - `next_worker` : **Supervisor가 다음 노드를 고르기 위한 라우팅 키**
# - `task_status` / `confidence` / `iteration_count` : **END로 가는 종료 키**
#
# ---
#
# ## 4) Supervisor의 “순서 조율”이 구현 관점에서 무엇을 의미하나?
#
# Supervisor의 순서 조율은 추상적인 “지휘”가 아니라, 아래 구현 패턴으로 나타납니다.
#
# - Supervisor는 현재 `State`를 보고
# - **`next_worker` 또는 `task_status`를 근거로**
# - **조건부 엣지**로 다음 노드(Worker)를 선택하고
# - 종료 조건이면 **END**로 전이
#
# 즉, “순서”는 다음 중 하나(또는 조합)로 state에 반영됩니다.
#
# - `next_worker` 값을 갱신해 다음 노드를 결정
# - `task_status="done"`을 설정해 END 전이 트리거
# - `iteration_count`, `confidence`를 근거로 재시도/검증 라우팅
#
# ---
#
# ## 5) ReAct는 “선택적 구현 디테일” + state 업데이트 계약을 고정하면 ReAct가 달라도 동작
#
# 하위 에이전트가 **ReAct(생각↔행동, 필요 시 tool 호출)**로 구현되는 경우가 많지만, 중요한 것은 “반드시 ReAct여야 한다”가 아니라:
#
# - 하위 에이전트는 어떤 방식으로든
# - **결과를 state의 정해진 필드들에 기록**하고
# - Supervisor가 그 필드를 보고 라우팅/종료를 결정할 수 있어야 한다는 점입니다.
#
# 예:
# - Researcher는 tool 호출 후 `artifacts.research_notes`와 `confidence`에 기여
# - Writer는 `messages`에 초안 작성 결과를 추가
# - Verifier는 결함을 `artifacts.issues`로 남기고 `task_status`에 영향을 줄 수 있음(단, 최종 종료 결정은 Supervisor가)
#
# ---
#
# ## 6) “종료 조건”이 state–전이(END)와 연결되는 방식(명시)
#
# 종료는 보통 Supervisor가 아래 로직으로 판단하고 END로 전이합니다.
#
# - **단계 완료**: `task_status == "done"`
# - **품질 임계치**: `confidence >= threshold`
# - **반복 제한**: `iteration_count >= max_iter`
# - **실패/진행불가**: `task_status == "failed"`
#
# 여기서 연결고리는 이겁니다.
#
# - Worker가 state(예: `confidence`, `artifacts`, `task_status 후보`)를 갱신 →
# - Supervisor가 state를 읽어 조건을 만족하면 END로 조건부 전이.
#
# ---
#
# ## 7) 역할/흐름을 “고정된 화살표”로 요약
#
# 1. **초기 state 구성**
# 2. **Supervisor가 state를 읽고** 조건부 엣지로 다음 Worker 선택
# 3. **Worker가 실행하고 state를 업데이트**(결과 기록)
# 4. 다시 **Supervisor로 돌아와** state를 바탕으로 다음 Worker 또는 END 결정
# 5. 종료 조건 만족 시 **END**
#
# ---
#
# ## 8) 마지막으로 한 문장 요약(요구 반영: 라우팅·종료가 state와 어떻게 연결되는지)
#
# **LangGraph Supervisor 기반 멀티 에이전트 패턴은, 하위 에이전트가 state를 갱신하고(Sate update), Supervisor가 state 필드(`next_worker`, `task_status`, `confidence`, `iteration_count` 등)를 조건부 엣지의 입력으로 사용해 다음 전이를 라우팅하거나 종료(END)하는 구조입니다.**
#
# ---
#
# 원하시면, 위 설명을 바탕으로 **(1) Supervisor가 `next_worker`를 어떻게 결정하는지 라우팅 함수 의사코드**, **(2) END 조건 포함한 conditional edge 예시 템플릿**, **(3) Worker가 state에 어떤 필드를 “반드시” 써야 하는 계약서 형태**로도 바로 작성해드릴게요.
#
# === SCORE ===
# 8
#
# === REVISION ===
# 2
#
# === CRITIQUE ===
# SCORE: 8
#
# CRITIQUE:
# - 장점: “상태(state) 스키마 → state 필드(라우팅 키/상태 값) → 조건부 엣지로 라우팅 → 종료(END)”의 연결고리를 비교적 명확히 보강했고, Supervisor의 “순서 조율”을 구현 요소(conditional edges + 라우팅 키)로 구체화하려는 시도가 좋습니다. 또한 종료 조건(단계 완료/품질 임계치/반복 제한/실패)까지 포함한 점이 비평 요청에 부합합니다.
# - 개선 여지(핵심): 4절에서 “Supervisor가 결과를 state에 기록하고 다음 라우팅”이라고 쓴 뒤 곧이어 “일반적으로는 하위 에이전트가 기록하고 Supervisor가 결정”이라고 정정하는 흐름이 약간 혼동을 줍니다. 둘의 역할을 더 명확히(예: “상태 갱신 주체는 하위 에이전트, 라우팅 결정 주체는 Supervisor” 또는 반대로) 고정해서 문장을 정리하면 비평의 의도를 더 정확히 만족합니다.
# - 정확성/정밀도: LangGraph에서의 실제 표현(예: conditional edge의 형태, 라우팅 함수 시그니처, next_worker를 상태에서 읽는 방식 등)이 추상적으로 남아 있습니다. “거의 그대로 구현 가능한 템플릿”을 약속했으나, 본문에는 아직 구체 코드/구조 예시가 부족합니다.
# - 범위 균형: “ReAct는 선택”이라는 관점은 타당하지만, 그에 따른 state 업데이트 계약(어떤 필드에 무엇을 넣는지)이 함께 명시되면 “ReAct가 달라도 동작 가능”이 더 설득력 있게 됩니다.
# - 결론 문장: 6절 요약은 좋지만, 비평에서 요구한 “종료 조건과 라우팅/전이 조건의 state 연결”이 문장 요약에는 다소 약하게 반영되어 있습니다(요약에 DONE/threshold/iteration_count 중 하나라도 더 드러내면 더 좋음).

# %%
#  https://docs.langchain.com/  참고해서 코드 작성할것
