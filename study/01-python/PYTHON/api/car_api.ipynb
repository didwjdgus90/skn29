# %% [markdown]
# 공공 데이터 포털
#
# https://www.data.go.kr/index.do
#
# 일반 인증키 : a3e65adc766456f710b21fc47609aba0ec796f2dca19a37631b48d8d687c9ae5

# %%
import requests
import xml.etree.ElementTree as ET
import os
from dotenv import load_dotenv
load_dotenv()

service_key = os.getenv('PUBLIC_SERVICE_KEY')
url = "https://apis.data.go.kr/B553881/newRegistlnfoService_02/getnewRegistlnfoService02"

params = {
    'serviceKey' : service_key,
    'registYy' : '2025',
    'registMt' : '01',
    'vhctyAsortCode' : 1,
    'registGrcCode' : 1
}
response = requests.get(url,params = params)
print(f'코드 : {response.status_code}')
print(response.text)
root = ET.fromstring(response.text)
for child in root.find('header'): # Element 객체
    print(child.tag, child.text)
for child in root.find('body'): # Element 객체
    print(child.tag, child.text)
# Out:
# 코드 : 200
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_CODE</resultMsg></header><body><dtaCo>12412</dtaCo></body></response>
# resultCode 00
# resultMsg NORMAL_CODE
# dtaCo 12412

# %%
# 문자열 xml 구조를 dick 객체로 변환
# %pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmltodict
data = xmltodict.parse(response.text)

print(data)
data.get('response').get('body').get('dtaCo')
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}, 'body': {'dtaCo': '9872'}}}
# '9872'

# %%
import requests
import xml.etree.ElementTree as ET
import os
from dotenv import load_dotenv
load_dotenv()

service_key = os.getenv('PUBLIC_SERVICE_KEY')
url = 'https://apis.data.go.kr/B553881/newRegistlnfoService_02/getnewRegistlnfoService02'

for month in range(1,13):
    params = {
    'serviceKey' : service_key,
    'registYy' : '2025',
    'registMt' : f'{month:02}',
    'vhctyAsortCode' :1,  # 승용
    'registGrcCode'   : 9,  # 서울
    'useFuelCode' : 5 # 하이브리드
    }
    response = requests.get(url,params=params)    
    root = ET.fromstring(response.text)
    print(root.findtext('body/dtaCo'))
# Out:
# 119
# 1196
# 1759
# 1737
# 2136
# 1884
# 2360
# 1860
# 2590
# 2094
# 1317
# 731
