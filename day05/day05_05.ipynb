# %%
# 데이터분석용 커스텀 예외 정의
# Exception 을 상속받아서 나만의 에러 만들기
# 클래스명 MissingDataError
# 상속 Exception

class MissingDataError(Exception):
    # 필수데이터가 누락되었을때 발생하는 에러
    def __init__(self, column_name):
        super().__init__(f'치명적인 오류 : {column_name} 컬럼의 데이터가 비었습니다.')


#데이터
test_data = { 'name' : '홍길동', 'age' : "", 'addr' : 'seoul' }

for key, value in test_data.items():
  try:
    if value == "":
      raise MissingDataError(key)
    else:
      print(f'{key} : {value}')
  except Exception as e:
    print(e)
# Out:
# name : 홍길동
# 치명적인 오류 : age 컬럼의 데이터가 비었습니다.
# addr : seoul
